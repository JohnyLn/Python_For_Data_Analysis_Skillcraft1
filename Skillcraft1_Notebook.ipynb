# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
skillcraft =  pd.read_csv("dataset/SkillCraft1_Dataset.csv", sep = ",")
skillcraft
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3390   10089            8   ?            ?          ?  259.6296
# 3391   10090            8   ?            ?          ?  314.6700
# 3392   10092            8   ?            ?          ?  299.4282
# 3393   10094            8   ?            ?          ?  375.8664
# 3394   10095            8   ?            ?          ?  348.3576
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# 1            0.003304         0.000259              4        0.000294
# 2            0.001101         0.000336              4        0.000294
# 3            0.001034         0.000213              1        0.000053
# 4            0.001136         0.000327              2        0.000000
# ...               ...              ...            ...             ...
# 3390         0.020425         0.000743              9        0.000621
# 3391         0.028043         0.001157             10        0.000246
# 3392         0.028341         0.000860              7        0.000338
# 3393         0.036436         0.000594              5        0.000204
# 3394         0.029855         0.000811              4        0.000224
#
#       MinimapRightClicks  NumberOfPACs  GapBetweenPACs  ActionLatency  \
# 0               0.000392      0.004849         32.6677        40.8673
# 1               0.000432      0.004307         32.9194        42.3454
# 2               0.000461      0.002926         44.6475        75.3548
# 3               0.000543      0.003783         29.2203        53.7352
# 4               0.001329      0.002368         22.6885        62.0813
# ...                  ...           ...             ...            ...
# 3390            0.000146      0.004555         18.6059        42.8342
# 3391            0.001083      0.004259         14.3023        36.1156
# 3392            0.000169      0.004439         12.4028        39.5156
# 3393            0.000780      0.004346         11.6910        34.8547
# 3394            0.001315      0.005566         20.0537        33.5142
#
#       ActionsInPAC  TotalMapExplored  WorkersMade  UniqueUnitsMade  \
# 0           4.7508                28     0.001397                6
# 1           4.8434                22     0.001194                5
# 2           4.0430                22     0.000745                6
# 3           4.9155                19     0.000426                7
# 4           9.3740                15     0.001174                4
# ...            ...               ...          ...              ...
# 3390        6.2754                46     0.000877                5
# 3391        7.1965                16     0.000788                4
# 3392        6.3979                19     0.001260                4
# 3393        7.9615                15     0.000613                6
# 3394        6.3719                27     0.001566                7
#
#       ComplexUnitsMade  ComplexAbilitiesUsed
# 0             0.000000              0.000000
# 1             0.000000              0.000208
# 2             0.000000              0.000189
# 3             0.000000              0.000384
# 4             0.000000              0.000019
# ...                ...                   ...
# 3390          0.000000              0.000000
# 3391          0.000000              0.000000
# 3392          0.000000              0.000000
# 3393          0.000000              0.000631
# 3394          0.000457              0.000895
#
# [3395 rows x 20 columns]

# %%
skillcraft.isnull().sum()
# Out:
# GameID                  0
# LeagueIndex             0
# Age                     0
# HoursPerWeek            0
# TotalHours              0
# APM                     0
# SelectByHotkeys         0
# AssignToHotkeys         0
# UniqueHotkeys           0
# MinimapAttacks          0
# MinimapRightClicks      0
# NumberOfPACs            0
# GapBetweenPACs          0
# ActionLatency           0
# ActionsInPAC            0
# TotalMapExplored        0
# WorkersMade             0
# UniqueUnitsMade         0
# ComplexUnitsMade        0
# ComplexAbilitiesUsed    0
# dtype: int64

# %%
for i in range(len(title)):
    count=0
    col=skillcraft.iloc[:, i]
    for j in range(len(col)):
        if col[j] == "?":
            count+=1
    print(str(title[i]) + " : " + str(count))
# Out:
# GameID : 0
# LeagueIndex : 0
# Age : 55
# HoursPerWeek : 56
# TotalHours : 57
# APM : 0
# SelectByHotkeys : 0
# AssignToHotkeys : 0
# UniqueHotkeys : 0
# MinimapAttacks : 0
# MinimapRightClicks : 0
# NumberOfPACs : 0
# GapBetweenPACs : 0
# ActionLatency : 0
# ActionsInPAC : 0
# TotalMapExplored : 0
# WorkersMade : 0
# UniqueUnitsMade : 0
# ComplexUnitsMade : 0
# ComplexAbilitiesUsed : 0

# %%
corr=skillcraft.corr(method='kendall')
corr
# Out:
#                         GameID  LeagueIndex       APM  SelectByHotkeys  \
# GameID                1.000000     0.051653  0.076858         0.070078
# LeagueIndex           0.051653     1.000000  0.527711         0.455273
# APM                   0.076858     0.527711  1.000000         0.627960
# SelectByHotkeys       0.070078     0.455273  0.627960         1.000000
# AssignToHotkeys       0.060987     0.390929  0.392936         0.479189
# UniqueHotkeys         0.079695     0.273423  0.259461         0.276109
# MinimapAttacks        0.049216     0.277989  0.203019         0.173387
# MinimapRightClicks    0.022161     0.174017  0.233302         0.135007
# NumberOfPACs          0.053937     0.466724  0.498034         0.381197
# GapBetweenPACs       -0.071328    -0.420917 -0.475336        -0.301749
# ActionLatency        -0.060246    -0.537338 -0.633637        -0.427637
# ActionsInPAC          0.034352     0.123918  0.330082         0.146727
# TotalMapExplored      0.020045     0.169719  0.191437         0.143701
# WorkersMade          -0.006218     0.248279  0.314488         0.233327
# UniqueUnitsMade       0.015180     0.102473  0.097510         0.069511
# ComplexUnitsMade     -0.015079     0.133342  0.141494         0.113274
# ComplexAbilitiesUsed -0.014399     0.131472  0.086729         0.083293
#
#                       AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# GameID                       0.060987       0.079695        0.049216
# LeagueIndex                  0.390929       0.273423        0.277989
# APM                          0.392936       0.259461        0.203019
# SelectByHotkeys              0.479189       0.276109        0.173387
# AssignToHotkeys              1.000000       0.302064        0.177589
# UniqueHotkeys                0.302064       1.000000        0.153895
# MinimapAttacks               0.177589       0.153895        1.000000
# MinimapRightClicks           0.119120       0.094907        0.221150
# NumberOfPACs                 0.326289       0.263803        0.140300
# GapBetweenPACs              -0.281118      -0.186115       -0.207634
# ActionLatency               -0.349269      -0.243655       -0.174334
# ActionsInPAC                 0.074270       0.006509        0.114907
# TotalMapExplored             0.147544       0.200612        0.138872
# WorkersMade                  0.168705       0.095914        0.080018
# UniqueUnitsMade              0.116692       0.172601        0.101524
# ComplexUnitsMade             0.142262       0.115584        0.060445
# ComplexAbilitiesUsed         0.166374       0.071286        0.040514
#
#                       MinimapRightClicks  NumberOfPACs  GapBetweenPACs  \
# GameID                          0.022161      0.053937       -0.071328
# LeagueIndex                     0.174017      0.466724       -0.420917
# APM                             0.233302      0.498034       -0.475336
# SelectByHotkeys                 0.135007      0.381197       -0.301749
# AssignToHotkeys                 0.119120      0.326289       -0.281118
# UniqueHotkeys                   0.094907      0.263803       -0.186115
# MinimapAttacks                  0.221150      0.140300       -0.207634
# MinimapRightClicks              1.000000      0.109032       -0.193822
# NumberOfPACs                    0.109032      1.000000       -0.353344
# GapBetweenPACs                 -0.193822     -0.353344        1.000000
# ActionLatency                  -0.169972     -0.685799        0.482343
# ActionsInPAC                    0.236230     -0.107910       -0.266796
# TotalMapExplored                0.135855      0.341432       -0.063551
# WorkersMade                     0.175074      0.213142       -0.171656
# UniqueUnitsMade                 0.133193      0.225787       -0.046306
# ComplexUnitsMade                0.098782      0.166199       -0.044325
# ComplexAbilitiesUsed            0.078754      0.141875       -0.055462
#
#                       ActionLatency  ActionsInPAC  TotalMapExplored  \
# GameID                    -0.060246      0.034352          0.020045
# LeagueIndex               -0.537338      0.123918          0.169719
# APM                       -0.633637      0.330082          0.191437
# SelectByHotkeys           -0.427637      0.146727          0.143701
# AssignToHotkeys           -0.349269      0.074270          0.147544
# UniqueHotkeys             -0.243655      0.006509          0.200612
# MinimapAttacks            -0.174334      0.114907          0.138872
# MinimapRightClicks        -0.169972      0.236230          0.135855
# NumberOfPACs              -0.685799     -0.107910          0.341432
# GapBetweenPACs             0.482343     -0.266796         -0.063551
# ActionLatency              1.000000     -0.112359         -0.250659
# ActionsInPAC              -0.112359      1.000000         -0.065477
# TotalMapExplored          -0.250659     -0.065477          1.000000
# WorkersMade               -0.239700      0.224470          0.117950
# UniqueUnitsMade           -0.146002     -0.066284          0.448475
# ComplexUnitsMade          -0.146370      0.049496          0.295768
# ComplexAbilitiesUsed      -0.133323     -0.014605          0.206048
#
#                       WorkersMade  UniqueUnitsMade  ComplexUnitsMade  \
# GameID                  -0.006218         0.015180         -0.015079
# LeagueIndex              0.248279         0.102473          0.133342
# APM                      0.314488         0.097510          0.141494
# SelectByHotkeys          0.233327         0.069511          0.113274
# AssignToHotkeys          0.168705         0.116692          0.142262
# UniqueHotkeys            0.095914         0.172601          0.115584
# MinimapAttacks           0.080018         0.101524          0.060445
# MinimapRightClicks       0.175074         0.133193          0.098782
# NumberOfPACs             0.213142         0.225787          0.166199
# GapBetweenPACs          -0.171656        -0.046306         -0.044325
# ActionLatency           -0.239700        -0.146002         -0.146370
# ActionsInPAC             0.224470        -0.066284          0.049496
# TotalMapExplored         0.117950         0.448475          0.295768
# WorkersMade              1.000000         0.100853          0.172986
# UniqueUnitsMade          0.100853         1.000000          0.404886
# ComplexUnitsMade         0.172986         0.404886          1.000000
# ComplexAbilitiesUsed     0.085538         0.338722          0.550040
#
#                       ComplexAbilitiesUsed
# GameID                           -0.014399
# LeagueIndex                       0.131472
# APM                               0.086729
# SelectByHotkeys                   0.083293
# AssignToHotkeys                   0.166374
# UniqueHotkeys                     0.071286
# MinimapAttacks                    0.040514
# MinimapRightClicks                0.078754
# NumberOfPACs                      0.141875
# GapBetweenPACs                   -0.055462
# ActionLatency                    -0.133323
# ActionsInPAC                     -0.014605
# TotalMapExplored                  0.206048
# WorkersMade                       0.085538
# UniqueUnitsMade                   0.338722
# ComplexUnitsMade                  0.550040
# ComplexAbilitiesUsed              1.000000

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Generate a custom diverging colormap
cmap = seaborn.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
