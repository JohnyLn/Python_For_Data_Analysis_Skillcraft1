# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
skillcraft =  pd.read_csv("dataset/SkillCraft1_Dataset.csv", sep = ",")
skillcraft
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3390   10089            8   ?            ?          ?  259.6296
# 3391   10090            8   ?            ?          ?  314.6700
# 3392   10092            8   ?            ?          ?  299.4282
# 3393   10094            8   ?            ?          ?  375.8664
# 3394   10095            8   ?            ?          ?  348.3576
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...

# %%
skillcraft.isnull().sum()
# Out:
# GameID                  0
# LeagueIndex             0
# Age                     0
# HoursPerWeek            0
# TotalHours              0
# APM                     0
# SelectByHotkeys         0
# AssignToHotkeys         0
# UniqueHotkeys           0
# MinimapAttacks          0
# MinimapRightClicks      0
# NumberOfPACs            0
# GapBetweenPACs          0
# ActionLatency           0
# ActionsInPAC            0
# TotalMapExplored        0
# WorkersMade             0
# UniqueUnitsMade         0
# ComplexUnitsMade        0
# ComplexAbilitiesUsed    0
# dtype: int64

# %%
title = skillcraft.columns
title
# Out:
# Index(['GameID', 'LeagueIndex', 'Age', 'HoursPerWeek', 'TotalHours', 'APM',
#        'SelectByHotkeys', 'AssignToHotkeys', 'UniqueHotkeys', 'MinimapAttacks',
#        'MinimapRightClicks', 'NumberOfPACs', 'GapBetweenPACs', 'ActionLatency',
#        'ActionsInPAC', 'TotalMapExplored', 'WorkersMade', 'UniqueUnitsMade',
#        'ComplexUnitsMade', 'ComplexAbilitiesUsed'],
#       dtype='object')

# %%
for i in range(len(title)):
    count=0
    col=skillcraft.iloc[:, i]
    for j in range(len(col)):
        if col[j] == "?":
            count+=1
    print(str(title[i]) + " : " + str(count))
# Out:
# GameID : 0
# LeagueIndex : 0
# Age : 55
# HoursPerWeek : 56
# TotalHours : 57
# APM : 0
# SelectByHotkeys : 0
# AssignToHotkeys : 0
# UniqueHotkeys : 0
# MinimapAttacks : 0
# MinimapRightClicks : 0
# NumberOfPACs : 0
# GapBetweenPACs : 0
# ActionLatency : 0
# ActionsInPAC : 0
# TotalMapExplored : 0
# WorkersMade : 0
# UniqueUnitsMade : 0
# ComplexUnitsMade : 0
# ComplexAbilitiesUsed : 0

# %%
import missingno as msno
# %matplotlib inline

# %%
miss = skillcraft
for i in range(len(title)):
    col=miss.iloc[:, i]
    for j in range(len(col)):
        if col[j] == "?":
            col[j] = None
miss
# Out:
# <ipython-input-7-6fdf74313878>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[j] = None
#       GameID  LeagueIndex   Age HoursPerWeek TotalHours       APM  \
# 0         52            5    27           10       3000  143.7180
# 1         55            5    23           10       5000  129.2322
# 2         56            4    30           10        200   69.9612
# 3         57            3    19           20        400  107.6016
# 4         58            3    32           10        500  122.8908
# ...      ...          ...   ...          ...        ...       ...
# 3390   10089            8  None         None       None  259.6296
# 3391   10090            8  None         None       None  314.6700
# 3392   10092            8  None         None       None  299.4282
# ...

# %%
df_del = skillcraft
ind = []
for i in range(len(df_del.TotalHours)):
    if df_del.TotalHours[i] == "?":
        ind.append(i)
        
df_del = df_del.drop(index=df_del.index[ind])
df_del
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3335    9261            4  20            8        400  158.1390
# 3336    9264            5  16           56       1500  186.1320
# 3337    9265            4  21            8        100  121.6992
# 3338    9270            3  20           28        400  134.2848
# 3339    9271            4  22            6        400   88.8246
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...

# %%
msno.matrix(df_del)

# %%
df_del
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3335    9261            4  20            8        400  158.1390
# 3336    9264            5  16           56       1500  186.1320
# 3337    9265            4  21            8        100  121.6992
# 3338    9270            3  20           28        400  134.2848
# 3339    9271            4  22            6        400   88.8246
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...
